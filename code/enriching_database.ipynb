# %% [markdown]
# # A Correspondence Contextualised
# This is a script for enriching existing data about keywords or person information with information from [Wikidata](https://www.wikidata.org/wiki/Wikidata:Main_Page).

# %%
import pandas as pd

# %%
df = pd.read_excel('../data/cds_sheets/Kopie_von_20220816_sachindex_cds.xlsx')

# print(df[df['Sachindex'].str.contains("/")==True]['Sachindex'].str.split('/'))
df_merged = (df.set_index(df.columns.drop('Deutsch',1).tolist()).Deutsch.str.split('/', expand=True).stack().reset_index().rename(columns={0:'Deutsch'}).loc[:, df.columns])
df_merged.to_csv('../data/retrieved/sachindex_singular_values.csv')

# %%
import requests
index = 0
for string in df_merged['Deutsch']:
    url = 'https://query.wikidata.org/sparql'
    query = f'' \
            f'SELECT ?item ?label_fr ' \
            f'  WHERE {{' \
            f'      ?item rdfs:label "{string}"@de. ' \
            f'      ?item rdfs:label ?label_fr filter (lang(?label_fr) = "fr").' \
            f'  }}'
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()
    print(data)
    #df_merged['Wikidata'][index] = [item['item']['value'] for item in data['results']['bindings']]


#print(df_merged)
# Out:
# {'head': {'vars': ['item', 'label_fr']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2809816'}, 'label_fr': {'xml:lang': 'fr', 'type': 'literal', 'value': '1814 (nombre)'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4554012'}, 'label_fr': {'xml:lang': 'fr', 'type': 'literal', 'value': '1814'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6943'}, 'label_fr': {'xml:lang': 'fr', 'type': 'literal', 'value': '1814'}}]}}
# {'head': {'vars': ['item', 'label_fr']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q12681633'}, 'label_fr': {'xml:lang': 'fr', 'type': 'literal', 'value': '1815'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q6948'}, 'label_fr': {'xml:lang': 'fr', 'type': 'literal', 'value': '1815'}}]}}
# ...
